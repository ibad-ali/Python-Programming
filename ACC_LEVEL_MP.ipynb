# %%
import sys
from pprint import pprint
from pymongo import MongoClient
from datetime import datetime
import math

t1 = datetime.now()


zna_acct_attributes = ['corporate_email_address','business_registration_number','are_you_a_united_states_citizen_green_card_holder_resident','business_incorporation_number','date_of_incorporation','place_of_incorporation','sales_tax_registration_number','secp_registration_number','secp_registration_date','name_of_financial_institution','post_code_of_country_of_incorporation','address_as_per_w8bene','reason_of_no_tax_identification_number','foreign_tax_no_usa_tin_ssn','country_of_tax_residence','business_name','profession','next_of_kin_name','relationship_to_kin','address_of_kin','next_of_kin_telephone_number','relationship_with_guardian','relationship_with_beneficial_owner','other_bank_name','is_customer_beneficial_owner_of_funds','capacity','business_details','date_of_registration','expected_turnover_in_the_next_12_months','us_residence_card_number','number_of_employees','average_monthly_balance_bucket','foreign_contact_number','country_where_the_most_senior_position_is_was_held_of_pep','analysis_of_pep','membership_number_of_trade_body','beneficial_owner_of_foreign_bank_transfer','expected_monthly_foreign_bank_transfer_amount','inward_remittance_country','outward_remittance_country','purpose_of_foreign_transfer','foreign_or_domestic_pep_y_n','shareholder_customer_number','shareholder_role','shareholding_percentage','brief_description_of_business_geographical_areas_operations_supplier_and_counter_parties','counter_party_products_services_provided_as_part_of_business_transactions','countries_with_expected_foreign_transfer','does_the_company_have_subsidiaries','country_of_operations','expected_monthly_remittance_amount','expiry_date_of_residence_card','declaration_date_of_us_person','did_you_spend_a_minimum_of_183_days_in_the_us_in_the_last_3_year_period','do_you_hold_tax_residency_of_any_country_jurisdiction_other_than_pakistan_and_or_united_states','industry_type','name_of_counter_party','have_you_renounced_your_us_citizenship_residency','irs_form_w8_submitted','irs_form_w9_submitted','period_for_which_the_most_senior_position_was_held','expected_modes_of_credit_transactions','power_of_attorney_third_party_mandate_y_n','purpose_of_inward_remittance','purpose_of_outward_remittance','reason_for_attorney_third_party_mandate_y_n','reason_for_no_pass_book_copy_obtained','overseas_residence_card_number','registered_unregistered','source_of_income_industry','source_of_income_of_landlord','subsidiary_geography','us_address','us_telephone_number','preferred_mode_of_contact','subsidiary_name','type_of_economic_activity','is_any_of_the_directors_trustee_partners_a_pep','number_of_dependents','qualification','salary_is_credited_in_hbl','owners_proprietors_name','owners_proprietors_cnic_number',
                       'shareholder_first_name','shareholder_middle_name','shareholder_last_name',
'shareholder_title','shareholder_designation','identification_document_number_of_shareholder','account_opening_date']


src_attributes = {
                  'ZNA_ACCOUNT': zna_acct_attributes,
                 }

SenstivityDict = {
'expiry_date_of_residence_card': 30,
'birth_place': 30,
'country_of_birth': 30,
'date_of_birth': 30,
'gender': 30,
'identification_document_date_of_expiry': 30,
'identification_document_date_of_issue': 30,
'mailing_address':20,
'house_appt_office_no_or_name_office':20,
'house_appt_office_no_or_name_permanent':20,
'house_appt_office_no_or_name_residential':20,
'street_office':20,
'street_permanent':20,
'street_prime':20,
'street_residential':20,
'corporate_email_address':20,
'personal_email_address':20,
'personal_email_address_1':20,
'personal_email_address_2':20,
'address_contact_number_office':20,
'address_contact_number_residential':20,
'land_line_no_pakistan_address_office':20,
'land_line_no_pakistan_address_permanent':20,
'land_line_no_pakistan_address_prime':20,
'land_line_no_pakistan_address_residential':20,
'mobile_no_pakistan':20,
'mobile_no_pakistan_1':20,
'mobile_no_pakistan_address_office':20,
'mobile_no_pakistan_address_permanent':20,
'mobile_no_pakistan_address_prime':20,
'mobile_no_pakistan_address_residential':20,
'whatsapp_number':20,
'shareholder_designation':20,
'sales_tax_registration_number':20,
'foreign_tax_no_usa_tin_ssn':20,
'foreign_tax_number':20,
'us_contact_number':20,
'us_telephone_number':20,
'is_customer_visually_impaired':20,
'other_bank_account_number':20,
'foreign_contact_number':20,
'source_of_income':20,
'source_of_income_expected_annual_amount':20,
'source_of_wealth':20,
'beneficial_owner_nationality':20,
'designation':20,
'email_address_of_legal_heir':20,
'employer_name':20,
'father_name':20,
'fathers_name':20,
'first_name':20,
'foreign_passport_number':20,
'last_name':20,
'middle_name':20,
'nationality':20,
'spouse_name':20,
'title':20,
'area_district_office':10,
'area_district_permanent':10,
'area_district_prime':10,
'area_district_residential':10,
'post_zip_code_office':10,
'post_zip_code_permanent':10,
'post_zip_code_residential':10,
'any_extension':10,
'fax_number':10,
'province':10,
'type_of_addr':10,
'preferred_mode_of_contact':10,
'dialing_code':10,
'city_office':10,
'city_permanent':10,
'city_prime':10,
'city_residential':10,
'country_office':10,
'country_permanent':10,
'country_prime':10,
'country_residential':10,
'identification_document_number_of_shareholder':10,
'identification_document_number_of_shareholder_1':10,
'identification_document_number_of_shareholder_2':10,
'shareholder_customer_number':10,
'shareholder_role':10,
'shareholding_percentage':10,
'average_ticket_size_month':10,
'avg_no_of_expected_transactions_month':10,
'business_details':10,
'country_of_operations':10,
'expected_modes_of_credit_transactions':10,
'expected_monthly_income':10,
'merchant_classification':10,
'nature_of_business':10,
'number_of_employees':10,
'type_of_economic_activity':10,
'business_incorporation_number':10,
'business_registration_number':10,
'date_of_incorporation':10,
'date_of_permission_letter':10,
'date_of_posting_order':10,
'date_of_request_letter':10,
'do_you_deliver_goods_internationally':10,
'group_company_name':10,
'legal_business_name':10,
'membership_number_of_trade_body':10,
'place_of_incorporation':10,
'registered_unregistered':10,
'sbp_fund_allocation_reference_date':10,
'sbp_fund_allocation_reference_number':10,
'secp_registration_date':10,
'secp_registration_number':10,
'address_as_per_w8bene':10,
'are_you_a_united_states_citizen_green_card_holder_resident':10,
'are_you_or_have_you_ever_been_a_citizen_or_tax_resident_of_a_country_other_than_pakistan':10,
'country_of_citizenship':10,
'country_of_incorporation':10,
'declaration_date_of_us_person':10,
'did_you_spend_a_minimum_of_183_days_in_the_us_in_the_last_3_year_period':10,
'do_you_hold_tax_residency_of_any_country_jurisdiction_other_than_pakistan_and_or_United_States':10,
'entity_type':10,
'fatca_classification':10,
'have_you_renounced_your_us_citizenship_residency':10,
'irs_form_w8_submitted':10,
'irs_form_w9_submitted':10,
'name_of_financial_institution':10,
'overseas_residence_card_number':10,
'post_code_of_country_of_incorporation':10,
'reason_of_no_tax_identification_number':10,
'us_address':10,
'capacity':10,
'is_customer_beneficial_owner_of_funds':10,
'other_bank_name':10,
'analysis_of_pep':10,
'average_monthly_balance_bucket':10,
'beneficial_owner_of_foreign_bank_transfer':10,
'brief_description_of_business_geographical_areas_operations_supplier_and_counter_parties':10,
'counter_party_products_services_provided_as_part_of_business_transactions':10,
'countries_with_expected_foreign_transfer':10,
'country_where_the_most_senior_position_is_was_held_of_pep':10,
'customers_brief_comments':10,
'date_of_customer_meeting_kyc_update':10,
'does_the_company_have_subsidiaries':10,
'expected_monthly_foreign_bank_transfer_amount':10,
'high_risk_entity_as_per_bank_policy_y_n':10,
'industry_type':10,
'inward_remittance_country':10,
'is_any_of_the_directors_trustee_partners_a_pep':10,
'is_customer_pep':10,
'is_merchant_a_pep_or_family_member_close_relative_associate':10,
'name_of_counter_party':10,
'outward_remittance_country':10,
'period_for_which_the_most_senior_position_was_held':10,
'power_of_attorney_third_party_mandate_y_n':10,
'public_figure':10,
'purpose_of_foreign_transfer':10,
'purpose_of_inward_remittance':10,
'purpose_of_outward_remittance':10,
'reason_for_attorney_third_party_mandate_y_n':10,
'reason_for_no_pass_book_copy_obtained':10,
'source_of_income_industry':10,
'source_of_income_of_landlord':10,
'subsidiary_geography':10,
'subsidiary_name':10,
'address_of_kin':10,
'age_of_legal_heir':10,
'beneficial_owner_identification_document_number':10,
'beneficial_owner_name':10,
'beneficiary_owner_name':10,
'beneficiary_owner_name_1':10,
'business_name':10,
'caste':10,
'customer_number':10,
'customer_segment':10,
'customer_type':10,
'does_owner_know_how_to_use_a_computer':10,
'employed_since':10,
'identification_document_number':10,
'identification_document_type':10,
'is_hbl_employee':10,
'marital_status':10,
'multiple_nationality':10,
'name_of_legal_heir':10,
'next_of_kin_telephone_number':10,
'number_of_children':10,
'number_of_dependents':10,
'owners_ntn_number':10,
'profession':10,
'relationship_to_kin':10,
'relationship_with_beneficial_owner':10,
'relationship_with_guardian':10,
'relationship_with_legal_heir':10,
'salary_is_credited_in_hbl':10,
'owners_proprietors_cnic_number': 10,
'shareholder_first_name': 20,
'shareholder_middle_name': 20,
'shareholder_last_name': 20,
'shareholder_title': 20,
'shareholder_designation': 20,
'identification_document_number_of_shareholder': 10
    

}

def get_attrs(c, attr_type):
    attr_dict = {}
    for attr in src_attributes[attr_type]:
        try:
            if attr != 'subdomain' and c[attr] != 'null' and  c[attr].strip() != '':
                level = ''
                if attr[-1].isnumeric():
                    level = attr[:-2]
                else:
                    level = attr
                if attr not in SenstivityDict.keys():
                    lvl = 0
                else:
                    lvl = SenstivityDict[level]
                attr_dict[attr] = {
                                    "attr_name": attr,
                                    "attr_value": c[attr],
                                    "attr_src": {
                                        "attr_src_table": 'null',
                                        "attr_src_col": 'null'
                                    },
                                    "created_on": t1.strftime("%Y-%m-%d"),
                                    "update_on": t1.strftime("%Y-%m-%d"),
                                    "sensitivity_level": lvl,
                                    "mdm_status": {
                                        "status": 'non_mastered',
                                        "Maker": {
                                            "name": 'null',
                                            "datetime": 'null',
                                            "comment" : 'null'
                                            },
                                        "Checker":{
                                            "name": 'null',
                                            "datetime": 'null',
                                            "comment" : 'null'
                                            }
                                    }
                                }
            else:
                pass
        except Exception as e:
            print("exception 1")
            print(e)
    return attr_dict

def fn(c, unit):
    try:
        dic = {
                            "set_type": 'null',
                            "set_number": 'null',
                            "subdomain": '{x}'.format(x=unit),
                            "product_number" : 'null',
                            "product_type" : 'null',
                            "product_rel_type" : 'null',
                            "set_status" : 'null',
                            "set_status": 'null',
                            "created": t1.strftime("%Y-%m-%d"),
                            "updated": t1.strftime("%Y-%m-%d"),
                            "sensitivity_level": 'null',
                            "mdm_status": {
                                    "status": 'null',
                                    "Maker": {
                                        "name": 'null',
                                        "datetime": 'null',
                                        "comment" : 'null'
                                        },
                                    "Checker":{
                                        "name": 'null',
                                        "datetime": 'null',
                                        "comment" : 'null'
                                        }
                                },
                            "attributes": get_attrs(c, unit)
                        }

    except Exception as e:
        print('In Exception')
        print(e)
        dic = {}
    return dic

def create_iparty(iparty_id, eod_date):
    client = MongoClient(host='10.200.146.162', port=27017)
    db = client.cmdm_final
    stg = db['cmdm__account__finall__stagingg']
    fnl = db['cmdm__account__final__mastered']
    cust = stg.find({'iparty_id': '{x}'.format(x=iparty_id), "eod_date":'{x}'.format(x=eod_date)})
    iparty = {
        'iparty_id': iparty_id,
        'sensitivity_level':'null',
        'src_customer': []}
    account_numbers = []
    for cus in cust:
        if cus['account_number'] not in account_numbers:
            src_customer = {
                'srcsystem': cus['srcsystem'],
                'cust_num': cus['cust_num'],
                'account_number': cus['account_number'],
                'external_account_number': cus['external_account_number'],
                'cust_type': cus['cust_type'],
                'catg_id': cus['catg_id'],
                'rel_type': 'null',
                'table_name': cus['table_name'],
                'col_name': cus['col_name'],
                "id": cus['id'],
                "valid_id": cus['valid_id'],
                "id_type": cus['id_type'],
                "party_id": cus['party_id'],
                "party_status": 'null',
                "start_date": t1.strftime("%Y-%m-%d"),
                "end_date": t1.strftime("%Y-%m-%d"),
                "is_primary": 'null',
                "sensitivity_level": 'null',
                "mdm_status": {
                                "status": 'null',
                                "Maker": {
                                    "name": 'null',
                                    "datetime": 'null',
                                    "comment" : 'null'
                                    },
                                "Checker":{
                                    "name": 'null',
                                    "datetime": 'null',
                                    "comment" : 'null'
                                    }
                            },
                "attribute_set": {}
            }
            iparty['src_customer'].append(src_customer)
            account_numbers.append(cus['account_number'])
        index = account_numbers.index(cus['account_number'])
        if cus['srcsystem'] == 'Misys':
            cus['unit'] = cus['subdomain']
        else:
            cus['unit'] = cus['srcsystem']
        iparty['src_customer'][index]['attribute_set'][cus['unit']] = fn(cus, cus['unit'])
    return iparty

def update_iparty(iparty_id, eod_date):
    new_ip = create_iparty(iparty_id, eod_date)
    client = MongoClient(host='10.200.146.162', port=27017)
    db = client.cmdm_final
    fnl = db['cmdm__account__final__mastered']
    hist = db['cmdm__account__final__history']
    old_ip = fnl.find_one({'iparty_id': '{x}'.format(x=iparty_id)})
    try:
        hist.insert(old_ip)
    except Exception as e:
        print("IN Exception")
        print(e)
    new_src_cus = new_ip['src_customer']
    old_src_cus = old_ip['src_customer']
    new_parties = [x['party_id'] for x in new_src_cus]
    for party in old_src_cus:
        if party['party_id'] not in new_parties:
            new_src_cus.append(party)
        else:
            attr_set = list(party['attribute_set'].keys())
            for attr in attr_set:
                if attr not in list(new_src_cus[new_parties.index(party['party_id'])]['attribute_set'].keys()):
                    new_src_cus[new_parties.index(party['party_id'])]['attribute_set'][attr] = party['attribute_set'][attr]
    filter_cond = { 'iparty_id': iparty_id}
    newvalues = { "$set": { 'src_customer': new_src_cus } }
    fnl.update_one(filter_cond, newvalues)

# %%
client = MongoClient(host='10.200.146.162', port=27017, connect=False)
db = client.cmdm_final
stg = db['cmdm__account__finall__stagingg']
fnl = db['cmdm__account__final__mastered']
ipartys = []
with open('cmdm_acct_iparty.csv') as f:
    for line in f:
        ipartys.append(line.split('\n')[0])
print(len(ipartys))
# Out:
# 2379542

# %%
from pymongo import MongoClient
import numpy as np
from multiprocessing import Pool
import time

client = MongoClient(host='10.200.146.162', port=27017)
db = client.cmdm_final
fnl = db['cmdm__account__final__mastered']

def process_n_insert(x):
    """specify parameters for multiprocessing & need to create one MongoClient connection for each process"""
    eod_date ='2022-07-28'
    # comments_fun = db_fun.test
    fnl.insert_one(create_iparty(x, eod_date))
    print("Moved to final")

for x in ipartys:
    process_n_insert(x)

    
# time1s = time.time()
# cpu_count = 3 # prep for multiprocessing, we leave one core for mongo
# pool = Pool(processes=cpu_count)   


# result = pool.map(process_n_insert, ipartys)
# pool.close()
# pool.terminate()
# time1f = time.time()
# print(time1f-time1s)
# Out:
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# Moved to final
# ...
